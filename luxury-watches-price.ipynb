# %% [markdown]
# # Luxury Watch
#
# **Column Details**
# * Brand: The brand of the watch.
# * Model: The model name or number of the watch.
# * Case Material: The material used to make the watch case (e.g., stainless steel, titanium, gold).
# * Strap Material: The material used to make the watch strap or bracelet (e.g., leather, rubber, metal).
# * Movement Type: The type of movement used in the watch (e.g., automatic, manual, quartz).
# * Water Resistance: The level of water resistance for the watch (e.g., 30 meters, 100 meters, 600 meters).
# * Case Diameter (mm): The diameter of the watch case in millimeters.
# * Case Thickness (mm): The thickness of the watch case in millimeters.
# * Band Width (mm): The width of the watch strap or bracelet in millimeters.
# * Dial Color: The color of the watch dial (e.g., black, blue, silver).
# * Crystal Material: The material used for the watch crystal (e.g., sapphire, mineral, hardlex).
# * Complications: Any additional functions or features beyond timekeeping (e.g., date display, chronograph, GMT).
# * Power Reserve: The amount of time the watch can run without winding or wearing (e.g., 48 hours, 72 hours).
# * Price (USD): The retail price of the watch in US dollars.

# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Luxurywatch.csv"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(path)
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
#     Movement Type Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# 0       Automatic       300 meters                40.0                13.00
# 1       Automatic       600 meters                43.5                14.47
# 2       Automatic       100 meters                41.0                13.00
# 3       Automatic        30 meters                43.0                14.25
# 4          Quartz        30 meters                31.0                 6.05
# ..            ...              ...                 ...                  ...
# 502     Automatic        30 meters                38.5                 8.25
# 503     Automatic       300 meters                45.0                15.50
# 504     Automatic        30 meters                38.5                 9.70
# 505     Automatic       150 meters                41.5                11.00
# 506     Automatic        50 meters                40.0                10.60
#
#      Band Width (mm) Dial Color Crystal Material Complications Power Reserve  \
# 0               20.0      Black         Sapphire          Date      48 hours
# 1               21.0       Blue         Sapphire          Date      60 hours
# 2               20.0      White         Sapphire   Chronograph      42 hours
# 3               22.0      Black         Sapphire   Chronograph      70 hours
# 4               20.0     Silver         Sapphire           NaN           NaN
# ..               ...        ...              ...           ...           ...
# 502             20.0      White         Sapphire          Date      38 hours
# 503             23.0      Black         Sapphire          Date     120 hours
# 504             20.0       Blue         Sapphire          Date      64 hours
# 505             22.0       Blue         Sapphire          Date      40 hours
# 506             20.0     Silver         Sapphire          Date      38 hours
#
#     Price (USD)
# 0         9,500
# 1         5,800
# 2         4,200
# 3         7,900
# 4         2,800
# ..          ...
# 502      21,500
# 503      13,500
# 504       1,800
# 505      19,000
# 506       1,200
#
# [507 rows x 14 columns]

# %%
df.describe().T
# Out:
#                      count       mean       std   min   25%   50%   75%   max
# Case Diameter (mm)   507.0  41.046154  2.535339  27.5  40.0  41.0  42.0  46.5
# Case Thickness (mm)  507.0  11.588343  2.491481   5.0   9.8  12.0  13.3  17.5
# Band Width (mm)      507.0  21.105523  1.658375  15.0  20.0  20.0  22.0  28.0

# %%
df.isna().sum()
# Out:
# Brand                    0
# Model                    0
# Case Material            0
# Strap Material           0
# Movement Type            0
# Water Resistance         0
# Case Diameter (mm)       0
# Case Thickness (mm)      0
# Band Width (mm)          0
# Dial Color               0
# Crystal Material         0
# Complications          122
# Power Reserve           14
# Price (USD)              1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                507 non-null    object
#  1   Model                507 non-null    object
#  2   Case Material        507 non-null    object
#  3   Strap Material       507 non-null    object
#  4   Movement Type        507 non-null    object
#  5   Water Resistance     507 non-null    object
#  6   Case Diameter (mm)   507 non-null    float64
#  7   Case Thickness (mm)  507 non-null    float64
#  8   Band Width (mm)      507 non-null    float64
#  9   Dial Color           507 non-null    object
#  10  Crystal Material     507 non-null    object
#  11  Complications        385 non-null    object
#  12  Power Reserve        493 non-null    object
#  13  Price (USD)          506 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 55.6+ KB

# %%
df_copia=df.copy()
df_copia['Price (USD)']=df_copia['Price (USD)'].str.replace(',', '').astype(float)
df_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                507 non-null    object
#  1   Model                507 non-null    object
#  2   Case Material        507 non-null    object
#  3   Strap Material       507 non-null    object
#  4   Movement Type        507 non-null    object
#  5   Water Resistance     507 non-null    object
#  6   Case Diameter (mm)   507 non-null    float64
#  7   Case Thickness (mm)  507 non-null    float64
#  8   Band Width (mm)      507 non-null    float64
#  9   Dial Color           507 non-null    object
#  10  Crystal Material     507 non-null    object
#  11  Complications        385 non-null    object
#  12  Power Reserve        493 non-null    object
#  13  Price (USD)          506 non-null    float64
# dtypes: float64(4), object(10)
# memory usage: 55.6+ KB

# %%
df_copia['Power Reserve'].value_counts()
# Out:
# Power Reserve
# 60 hours     82
# 42 hours     55
# 70 hours     50
# 50 hours     40
# 72 hours     38
# 120 hours    30
# 45 hours     29
# 48 hours     27
# 38 hours     27
# 40 hours     22
# 54 hours     15
# 46 hours     13
# 65 hours     11
# 55 hours     10
# 44 hours     10
# 56 hours      8
# 64 hours      6
# 68 hours      6
# 43 hours      5
# 80 hours      4
# 41 hours      1
# 4,200         1
# 210 days      1
# 270 days      1
# 168 hours     1
# Name: count, dtype: int64

# %%
df_copia['Power Reserve']=df_copia['Power Reserve'].replace('4,200', np.nan).replace('210 days', np.nan).replace('270 days', np.nan)

# %%
df_copia['Water Resistance in Meters']=df_copia['Water Resistance'].str.replace(' meters', '').astype(float)
df_copia['Power Reserve in Hours']= df_copia['Power Reserve'].str.replace(' hours', '').astype(float)

# %%
df_copia=df_copia.drop(df_copia[['Water Resistance', 'Power Reserve']], axis=1)
df_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Brand                       507 non-null    object
#  1   Model                       507 non-null    object
#  2   Case Material               507 non-null    object
#  3   Strap Material              507 non-null    object
#  4   Movement Type               507 non-null    object
#  5   Case Diameter (mm)          507 non-null    float64
#  6   Case Thickness (mm)         507 non-null    float64
#  7   Band Width (mm)             507 non-null    float64
#  8   Dial Color                  507 non-null    object
#  9   Crystal Material            507 non-null    object
#  10  Complications               385 non-null    object
#  11  Price (USD)                 506 non-null    float64
#  12  Water Resistance in Meters  507 non-null    float64
#  13  Power Reserve in Hours      490 non-null    float64
# dtypes: float64(6), object(8)
# memory usage: 55.6+ KB

# %%
df_copia=df_copia.dropna()
df_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 379 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Brand                       379 non-null    object
#  1   Model                       379 non-null    object
#  2   Case Material               379 non-null    object
#  3   Strap Material              379 non-null    object
#  4   Movement Type               379 non-null    object
#  5   Case Diameter (mm)          379 non-null    float64
#  6   Case Thickness (mm)         379 non-null    float64
#  7   Band Width (mm)             379 non-null    float64
#  8   Dial Color                  379 non-null    object
#  9   Crystal Material            379 non-null    object
#  10  Complications               379 non-null    object
#  11  Price (USD)                 379 non-null    float64
#  12  Water Resistance in Meters  379 non-null    float64
#  13  Power Reserve in Hours      379 non-null    float64
# dtypes: float64(6), object(8)
# memory usage: 44.4+ KB

# %%
from summarytools import dfSummary
dfSummary(df_copia)
# Out:
# <style type="text/css">
# #T_17907 thead>tr>th {
#   text-align: left;
# }
# #T_17907_row0_col0, #T_17907_row1_col0, #T_17907_row2_col0, #T_17907_row3_col0, #T_17907_row4_col0, #T_17907_row5_col0, #T_17907_row6_col0, #T_17907_row7_col0, #T_17907_row8_col0, #T_17907_row9_col0, #T_17907_row10_col0, #T_17907_row11_col0, #T_17907_row12_col0, #T_17907_row13_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_17907_row0_col1, #T_17907_row1_col1, #T_17907_row2_col1, #T_17907_row3_col1, #T_17907_row4_col1, #T_17907_row5_col1, #T_17907_row6_col1, #T_17907_row7_col1, #T_17907_row8_col1, #T_17907_row9_col1, #T_17907_row10_col1, #T_17907_row11_col1, #T_17907_row12_col1, #T_17907_row13_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_17907_row0_col2, #T_17907_row1_col2, #T_17907_row2_col2, #T_17907_row3_col2, #T_17907_row4_col2, #T_17907_row5_col2, #T_17907_row6_col2, #T_17907_row7_col2, #T_17907_row8_col2, #T_17907_row9_col2, #T_17907_row10_col2, #T_17907_row11_col2, #T_17907_row12_col2, #T_17907_row13_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_17907_row0_col3, #T_17907_row1_col3, #T_17907_row2_col3, #T_17907_row3_col3, #T_17907_row4_col3, #T_17907_row5_col3, #T_17907_row6_col3, #T_17907_row7_col3, #T_17907_row8_col3, #T_17907_row9_col3, #T_17907_row10_col3, #T_17907_row11_col3, #T_17907_row12_col3, #T_17907_row13_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_17907_row0_col4, #T_17907_row1_col4, #T_17907_row2_col4, #T_17907_row3_col4, #T_17907_row4_col4, #T_17907_row5_col4, #T_17907_row6_col4, #T_17907_row7_col4, #T_17907_row8_col4, #T_17907_row9_col4, #T_17907_row10_col4, #T_17907_row11_col4, #T_17907_row12_col4, #T_17907_row13_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_17907_row0_col5, #T_17907_row1_col5, #T_17907_row2_col5, #T_17907_row3_col5, #T_17907_row4_col5, #T_17907_row5_col5, #T_17907_row6_col5, #T_17907_row7_col5, #T_17907_row8_col5, #T_17907_row9_col5, #T_17907_row10_col5, #T_17907_row11_col5, #T_17907_row12_col5, #T_17907_row13_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_17907">
#   <caption><strong>Data Frame Summary</strong><br>df_copia<br>Dimensions: 379 x 14<br>Duplicates: 15</caption>
#   <thead>
#     <tr>
#       <th id="T_17907_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_17907_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_17907_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_17907_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_17907_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_17907_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_17907_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_17907_row0_col1" class="data row0 col1" ><strong>Brand</strong><br>[object]</td>
#       <td id="T_17907_row0_col2" class="data row0 col2" >1. Audemars Piguet<br>2. Zenith<br>3. Patek Philippe<br>4. IWC<br>5. Rolex<br>6. Blancpain<br>7. Omega<br>8. Vacheron Constantin<br>9. Hublot<br>10. Breitling<br>11. other</td>
#       <td id="T_17907_row0_col3" class="data row0 col3" >37 (9.8%)<br>29 (7.7%)<br>28 (7.4%)<br>28 (7.4%)<br>27 (7.1%)<br>24 (6.3%)<br>23 (6.1%)<br>21 (5.5%)<br>21 (5.5%)<br>16 (4.2%)<br>125 (33.0%)</td>
#       <td id="T_17907_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_17907_row1_col1" class="data row1 col1" ><strong>Model</strong><br>[object]</td>
#       <td id="T_17907_row1_col2" class="data row1 col2" >1. Royal Oak<br>2. Nautilus<br>3. Fifty Fathoms<br>4. Overseas<br>5. El Primero<br>6. Big Bang<br>7. Speedmaster<br>8. Laureato<br>9. Datejust<br>10. Portugieser<br>11. other</td>
#       <td id="T_17907_row1_col3" class="data row1 col3" >37 (9.8%)<br>26 (6.9%)<br>24 (6.3%)<br>21 (5.5%)<br>19 (5.0%)<br>18 (4.7%)<br>15 (4.0%)<br>14 (3.7%)<br>14 (3.7%)<br>13 (3.4%)<br>178 (47.0%)</td>
#       <td id="T_17907_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_17907_row2_col1" class="data row2 col1" ><strong>Case Material</strong><br>[object]</td>
#       <td id="T_17907_row2_col2" class="data row2 col2" >1. Stainless Steel<br>2. Titanium<br>3. Ceramic<br>4. Rose Gold<br>5. 18k Rose Gold<br>6. Carbon Fiber<br>7. 18k White Gold<br>8. Yellow Gold<br>9. 18k Yellow Gold<br>10. 18K Yellow Gold<br>11. other</td>
#       <td id="T_17907_row2_col3" class="data row2 col3" >335 (88.4%)<br>20 (5.3%)<br>7 (1.8%)<br>4 (1.1%)<br>3 (0.8%)<br>3 (0.8%)<br>2 (0.5%)<br>1 (0.3%)<br>1 (0.3%)<br>1 (0.3%)<br>2 (0.5%)</td>
#       <td id="T_17907_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_17907_row3_col1" class="data row3 col1" ><strong>Strap Material</strong><br>[object]</td>
#       <td id="T_17907_row3_col2" class="data row3 col2" >1. Stainless Steel<br>2. Leather<br>3. Rubber<br>4. Canvas<br>5. Fabric<br>6. Silicone<br>7. Jubilee Bracelet<br>8. Jubilee<br>9. Alligator<br>10. Textile<br>11. other</td>
#       <td id="T_17907_row3_col3" class="data row3 col3" >153 (40.4%)<br>133 (35.1%)<br>62 (16.4%)<br>9 (2.4%)<br>9 (2.4%)<br>3 (0.8%)<br>3 (0.8%)<br>2 (0.5%)<br>2 (0.5%)<br>1 (0.3%)<br>2 (0.5%)</td>
#       <td id="T_17907_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_17907_row4_col1" class="data row4 col1" ><strong>Movement Type</strong><br>[object]</td>
#       <td id="T_17907_row4_col2" class="data row4 col2" >1. Automatic<br>2. Manual</td>
#       <td id="T_17907_row4_col3" class="data row4 col3" >366 (96.6%)<br>13 (3.4%)</td>
#       <td id="T_17907_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_17907_row5_col1" class="data row5 col1" ><strong>Case Diameter (mm)</strong><br>[float64]</td>
#       <td id="T_17907_row5_col2" class="data row5 col2" >Mean (sd) : 41.2 (2.2)<br>min < med < max:<br>33.0 < 41.0 < 46.2<br>IQR (CV) : 1.6 (19.2)</td>
#       <td id="T_17907_row5_col3" class="data row5 col3" >30 distinct values</td>
#       <td id="T_17907_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_17907_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_17907_row6_col1" class="data row6 col1" ><strong>Case Thickness (mm)</strong><br>[float64]</td>
#       <td id="T_17907_row6_col2" class="data row6 col2" >Mean (sd) : 12.0 (2.2)<br>min < med < max:<br>7.5 < 12.4 < 16.9<br>IQR (CV) : 3.3 (5.5)</td>
#       <td id="T_17907_row6_col3" class="data row6 col3" >92 distinct values</td>
#       <td id="T_17907_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_17907_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id=

# %% [markdown]
# Si può notare dal pairplot che piu costosi sono omega e rolex, si può notare anche che ci sono vari brand con prezzi intermedi e molti con prezzi bassi, si può notare pero che gli orologi di maggior valore non hanno resistenza all'acqua e una riserva di potenza media

# %%
sns.pairplot(df_copia, hue='Brand', palette='coolwarm')

# %% [markdown]
# In questo pairplot invece si possono notare i materiali, lo zaffito è certamente quello più presente e con il prezzo maggiore nel dataset, si nota anche che alcuno con lo zaffiro possono avere una buona resiostenza all'acqua e una buona riserva di potenza

# %%
sns.pairplot(df_copia, hue='Crystal Material')
